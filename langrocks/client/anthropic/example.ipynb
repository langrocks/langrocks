# %% [markdown]
# # Demo for Computer Use tool with Anthropic
#
# In this recipe, we will demonstrate how to use the Computer Use tool with Anthropic. The Computer Use tool is a tool that provides anthropic access to a computer. It allows you to run commands on a computer and get the output.
#
# ## Setup Environment

# %%
# %pip install anthropic
# Out:
# I0000 00:00:1732121279.729246 3575529 work_stealing_thread_pool.cc:320] WorkStealingThreadPoolImpl::PrepareFork
# I0000 00:00:1732121279.729557 3575529 fork_posix.cc:77] Other threads are currently calling into gRPC, skipping fork() handlers
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import anthropic

# %% [markdown]
# ## Initialize the Computer Use tool

# %%
from langrocks.client.anthropic import ComputerTool
from IPython import display


computer = ComputerTool(url="localhost:50051")

# %%
response = await computer(action="key", text="ctrl+l")
response = await computer(action="type", text="https://www.google.com")
response = await computer(action="key", text="Return")
response = await computer(action="screenshot")
display.Image(url=f"data:image/png;base64,{response.base64_image}")
# Out:
# <img src="data:image/png;base64,..."/>
